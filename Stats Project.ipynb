# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('PSL Analytics Data 2.xlsx')

# %%
df
# Out:
#      Year Match Time  Match Number  Day  Month Match Date    Match Name  \
# 0    2016      Night             1    4      2 2016-02-04     1st Match
# 1    2016        Day             2    5      2 2016-02-05     2nd Match
# 2    2016      Night             3    5      2 2016-02-05     3rd Match
# 3    2016        Day             4    6      2 2016-02-06     4th Match
# 4    2016      Night             5    6      2 2016-02-06     5th Match
# ..    ...        ...           ...  ...    ...        ...           ...
# 145  2020      Night            30   15      3 2020-03-15    30th Match
# 146  2020      Night            31   14     11 2020-11-14     Qualifier
# 147  2020      Night            32   14     11 2020-11-14  Eliminator 1
# 148  2020      Night            33   15     11 2021-11-15  Eliminator 2
# 149  2020      Night            34   17     11 2021-11-17         Final
#
#       Concat                                  Teams              Team_1  \
# ...

# %%
df = df.drop('Match_Time', 1)
# Out:
# <ipython-input-87-62504f91d36f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Match_Time', 1)

# %%
df = df.drop('Concat', 1)
# Out:
# <ipython-input-88-0d5443af29ae>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Concat', 1)

# %%
df
# Out:
#      Year Match Time  Match Number  Day  Month Match Date    Match Name  \
# 0    2016      Night             1    4      2 2016-02-04     1st Match
# 1    2016        Day             2    5      2 2016-02-05     2nd Match
# 2    2016      Night             3    5      2 2016-02-05     3rd Match
# 3    2016        Day             4    6      2 2016-02-06     4th Match
# 4    2016      Night             5    6      2 2016-02-06     5th Match
# ..    ...        ...           ...  ...    ...        ...           ...
# 145  2020      Night            30   15      3 2020-03-15    30th Match
# 146  2020      Night            31   14     11 2020-11-14     Qualifier
# 147  2020      Night            32   14     11 2020-11-14  Eliminator 1
# 148  2020      Night            33   15     11 2021-11-15  Eliminator 2
# 149  2020      Night            34   17     11 2021-11-17         Final
#
#                                      Teams              Team_1  \
# ...

# %%
df.shape
# Out:
# (150, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           150 non-null    int64
#  1   Match Time     150 non-null    object
#  2   Match Number   150 non-null    int64
#  3   Day            150 non-null    int64
#  4   Month          150 non-null    int64
#  5   Match Date     150 non-null    datetime64[ns]
#  6   Match Name     150 non-null    object
#  7   Teams          150 non-null    object
#  8   Team_1         150 non-null    object
#  9   Team_2         150 non-null    object
#  10  Grounds        150 non-null    object
#  11  Countries      150 non-null    object
#  12  city           150 non-null    object
#  13  Match Winner   150 non-null    object
#  14  Outcome        150 non-null    object
#  15  Toss Outcome   150 non-null    object
#  16  Toss_Winner    150 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Match Time', 'Match Number', 'Day', 'Month', 'Match Date',
#        'Match Name', 'Teams', 'Team_1', 'Team_2', 'Grounds', 'Countries',
#        'city', 'Match Winner', 'Outcome', 'Toss Outcome', 'Toss_Winner',
#        'Toss_Decision'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# Year             False
# Match Time       False
# Match Number     False
# Day              False
# Month            False
# Match Date       False
# Match Name       False
# Teams            False
# Team_1           False
# Team_2           False
# Grounds          False
# Countries        False
# city             False
# Match Winner     False
# Outcome          False
# Toss Outcome     False
# Toss_Winner      False
# Toss_Decision    False
# dtype: bool

# %%
df.describe()
# Out:
#               Year  Match Number         Day       Month
# count   150.000000     150.00000  150.000000  150.000000
# mean   2018.200000      15.90000   14.860000    2.633333
# std       1.380594       9.31676    7.828729    1.471960
# min    2016.000000       1.00000    1.000000    2.000000
# 25%    2017.000000       8.00000    9.000000    2.000000
# 50%    2018.000000      15.50000   15.000000    2.000000
# 75%    2019.000000      23.00000   22.000000    3.000000
# max    2020.000000      34.00000   29.000000   11.000000

# %%
df['Year'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
df.iloc[df['Match Number'].idxmax()]
# Out:
# Year                                           2018
# Match Time                                    Night
# Match Number                                     34
# Day                                              25
# Month                                             3
# Match Date                      2018-03-25 00:00:00
# Match Name                                    Final
# Teams            Islamabad United vs Peshawar Zalmi
# Team_1                            Islamabad United
# Team_2                               Peshawar Zalmi
# Grounds                            National Stadium
# Countries                                  Pakistan
# city                                        Karachi
# Match Winner                       Islamabad United
# Outcome              Islamabad United won by 3 wkts
# Toss Outcome       Peshawar Zalmi, who chose to bat
# Toss_Winner                          Peshawar Zalmi
# Toss_Decision                                   bat
# Name: 81, dtype: object

# %%
df.hist(figsize=(18,15))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Match Number'}>],
#        [<AxesSubplot:title={'center':'Day'}>,
#         <AxesSubplot:title={'center':'Month'}>],
#        [<AxesSubplot:title={'center':'Match Date'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
fig_dims=(8,5)
fig,ax=plt.subplots(figsize=fig_dims)
sns.countplot(x='Year', ax=ax,data=df)
plt.show
x=[2016,2017,2018,2019,2020]
y=[24,24,34,34,34]
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha='center',va='bottom')
plt.savefig("Matches Played in Each year")

# %%
df1=df["Match Winner"].value_counts()
df1
# Out:
# Peshawar Zalmi                          31
# Quetta Gladiators                       30
# Islamabad United                        27
# Karachi Kings                           23
# Lahore Qalandars                        17
# Multan Sultans                          13
# Match tied/Match abandoned/No result     4
# -                                        4
# Quetta Gladiators                        1
# Name: Match Winner, dtype: int64

# %%
df1=df["Grounds"].value_counts()
df1
# Out:
# Dubai International Cricket Stadium    60
# Sharjah Cricket Stadium                40
# National Stadium                       21
# Gaddafi Stadium                        14
# Rawalpindi Cricket Stadium              8
# Sheikh Zayed Stadium                    4
# Multan Cricket Stadium                  2
# Multan Cricket Club Ground              1
# Name: Grounds, dtype: int64

# %%
fig_dims=(20,5)
fig,ax=plt.subplots(figsize=fig_dims)
g=sns.countplot(x=df['Grounds'], ax=ax,data=df)
for p in g.patches:
    g.annotate(f'{p.get_height():0.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    plt.savefig("Matches Played in different season in Different grounds")

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.countplot(x='Year', hue='Grounds', data=df,palette="magma",saturation=1)
for p in g.patches:
    g.annotate(f'{p.get_height():0.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=15)
plt.xlabel('\n Season',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Matches in Each Stadium Across Seasons',fontsize=12,fontweight="bold")
plt.savefig("Matches in Each Stadium Across Seasons")
plt.show()

# %%
df1=df["Match Winner"].value_counts()
g=sns.barplot(y=df1.index,x=df1)
g.annotate('31',xy=(31,0))
g.annotate('30',xy=(30,1))
g.annotate('27',xy=(27,2))
g.annotate('23',xy=(23,3))
g.annotate('17',xy=(17,4))
g.annotate('13',xy=(13,5))
g.annotate('4',xy=(4,6))
g.annotate('4',xy=(4,7))
g.annotate('1',xy=(1,8))
plt.savefig("Maximum matches win by team")

# %%
probability_of_winning=df['Toss_Winner'] == df['Match Winner']
probability_of_winning.groupby(probability_of_winning).size()
# Out:
# False    59
# True     91
# dtype: int64

# %%
g=sns.countplot(probability_of_winning)
g.annotate('59',xy=(0,59))
g.annotate('91',xy=(1,91))
plt.savefig("Probability that Toss Winner wins the match")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,4))
g=sns.countplot(df["Toss_Decision"][df['Toss_Winner'] == df['Match Winner']])
g.annotate('80',xy=(0,80))
g.annotate('9',xy=(1,9))
g.annotate('2',xy=(2,2))
plt.savefig("How Many Time Toss Decision of Toss Winner help him to win match")
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby('Year')['Match Winner'].value_counts()
# Out:
# Year  Match Winner
# 2016  Islamabad United                        7
#       Quetta Gladiators                       7
#       Peshawar Zalmi                          6
#       Karachi Kings                           2
#       Lahore Qalandars                        2
# 2017  Peshawar Zalmi                          6
#       Karachi Kings                           5
#       Quetta Gladiators                       5
#       Islamabad United                        4
#       Lahore Qalandars                        3
#       Match tied/Match abandoned/No result    1
# 2018  Islamabad United                        8
#       Peshawar Zalmi                          7
#       Karachi Kings                           5
#       Quetta Gladiators                       5
#       Multan Sultans                          4
#       Match tied/Match abandoned/No result    3
#       Lahore Qalandars                        2
# 2019  Quetta Gladiators                       9
# ...

# %%
df['Toss_Decision'].value_counts()
# Out:
# field    125
# bat       23
# -          2
# Name: Toss_Decision, dtype: int64

# %%
df['city'].value_counts()
# Out:
#  Dubai         60
#  Sharjah       40
#  Karachi       21
#  Lahore        14
#  Rawalpindi     8
#  Abu Dhabi      4
#  Multan         3
# Name: city, dtype: int64

# %%
df['Countries'].value_counts()
# Out:
# United Arab Emirates    104
# Pakistan                 46
# Name: Countries, dtype: int64

# %%
df['Grounds'].value_counts()
# Out:
# Dubai International Cricket Stadium    60
# Sharjah Cricket Stadium                40
# National Stadium                       21
# Gaddafi Stadium                        14
# Rawalpindi Cricket Stadium              8
# Sheikh Zayed Stadium                    4
# Multan Cricket Stadium                  2
# Multan Cricket Club Ground              1
# Name: Grounds, dtype: int64

# %%
df['Match Time'].value_counts()
# Out:
# Night    106
# Day       44
# Name: Match Time, dtype: int64

# %%
df['Match Name'].value_counts()
# Out:
# 1st Match       5
# 12th Match      5
# Final           5
# 20th Match      5
# 2nd Match       5
# 18th Match      5
# 17th Match      5
# 16th Match      5
# 15th Match      5
# 14th Match      5
# 13th Match      5
# 19th Match      5
# 11th Match      5
# 9th Match       5
# 8th Match       5
# 7th Match       5
# 6th Match       5
# 5th Match       5
# 4th Match       5
# 3rd Match       5
# 10th Match      5
# 26th Match      3
# Eliminator 1    3
# Qualifier       3
# 30th Match      3
# 29th Match      3
# 28th Match      3
# 27th Match      3
# 21st Match      3
# 25th Match      3
# 24th Match      3
# 23rd Match      3
# 22nd Match      3
# Eliminator 2    3
# 3rd Playoff     2
# 2nd Playoff     2
# 1st Playoff     2
# Name: Match Name, dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Islamabad United won by 5 wickets     7
# Karachi Kings won by 5 wickets        6
# Quetta Gladiators won by 8 wickets    5
# Quetta Gladiators won by 6 wickets    5
# Quetta Gladiators won by 5 wickets    5
#                                      ..
# Islamabad United won by 33 runs       1
# Lahore Qalandars won by 17 runs       1
# Lahore Qalandars won by 63 runs       1
# Peshawar Zalmi won by 1 runs          1
# Lahore Qalandars won by 25 runs       1
# Name: Outcome, Length: 93, dtype: int64

# %%
df['Toss_Winner'].value_counts()
# Out:
# Karachi Kings         33
# Quetta Gladiators     30
# Peshawar Zalmi        30
# Islamabad United      20
# Lahore Qalandars      20
# Multan Sultans        13
# Quetta Gladiators      2
# -                      2
# Name: Toss_Winner, dtype: int64

# %%
toss=df['Toss_Winner'].value_counts()
ax = plt.axes()
ax.set(facecolor = "grey")
sns.set(rc={'figure.figsize':(15,10)},style='darkgrid')
ax.set_title('No. of tosses won by each team',fontsize=15,fontweight="bold")
g=sns.barplot(y=toss.index, x=toss, orient='h',palette="icefire",saturation=1)
g.annotate('33',xy=(33,0))
g.annotate('30',xy=(30,1))
g.annotate('30',xy=(30,2))
g.annotate('20',xy=(20,3))
g.annotate('20',xy=(20,4))
g.annotate('13',xy=(13,5))
g.annotate('2',xy=(2,6))
g.annotate('2',xy=(2,7))
plt.xlabel('# of tosses won')
plt.ylabel('Teams')
plt.savefig("No of Toss Won by Each Team")
plt.show()

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.countplot(x='Year', hue='Toss_Decision', data=df,palette="magma",saturation=1)
for p in g.patches:
    g.annotate(f'{p.get_height():0.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=15)
plt.xlabel('\n Season',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Toss decision across seasons',fontsize=12,fontweight="bold")
plt.savefig("Toss Decision Across Seasons")
plt.show()

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.countplot(x='Year', hue='Match Time', data=df,palette="magma",saturation=1)
for p in g.patches:
    g.annotate(f'{p.get_height():0.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=15)
plt.xlabel('\n Season',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title('Match Time across seasons',fontsize=12,fontweight="bold")
plt.savefig("Match Time Across Seasons")
plt.show()

# %%
df_Bowling_Data=pd.read_excel('PSL Analytics Data 2.xlsx',sheet_name="Bowling Data")

# %%
df_Bowling_Data
# Out:
#      Year  Sr. No               Name       Age Skill               Team  Mats  \
# 0    2016       1      Andre Russell  32 years  RAFM   Islamabad United    10
# 1    2016       2         Wahab Riaz  35 years  LAFM     Peshawar Zalmi     9
# 2    2016       3     Mohammad Nawaz  26 years   LAO  Quetta Gladiators    10
# 3    2016       4      Mohammad Sami  39 years  RAMF   Islamabad United     7
# 4    2016       5      Grant Elliott  41 years  RAFM  Quetta Gladiators     6
# ..    ...     ...                ...       ...   ...                ...   ...
# 651  2021     126     Jonathan Wells  33 years  RAMF                NaN     2
# 652  2021     127  Najibullah Zadran  29 years  RAOB                NaN     5
# 653  2021     128      Rilee Rossouw  32 years  RAOB                NaN    12
# 654  2021     129     Sohaib Maqsood  35 years  RAOB                NaN    12
# 655  2021     130          Joe Denly  36 years  RALB                NaN     2
#
# ...

# %%
df_Bowling_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     656 non-null    int64
#  1   Sr. No   656 non-null    int64
#  2   Name     656 non-null    object
#  3   Age      654 non-null    object
#  4   Skill    569 non-null    object
#  5   Team     352 non-null    object
#  6   Mats     656 non-null    int64
#  7   Balls    410 non-null    float64
#  8   Mdns     410 non-null    float64
#  9   Runs     410 non-null    float64
#  10  Wkts     410 non-null    float64
#  11  BB       410 non-null    object
#  12  Ave      451 non-null    object
#  13  4wl      656 non-null    int64
#  14  5wl      656 non-null    int64
#  15  S. Rate  451 non-null    object
#  16  Econ     410 non-null    float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 87.2+ KB

# %%
df_Bowling_Data.dropna(subset = ["Skill"], inplace=True)

# %%
df_Bowling_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 0 to 655
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     569 non-null    int64
#  1   Sr. No   569 non-null    int64
#  2   Name     569 non-null    object
#  3   Age      568 non-null    object
#  4   Skill    569 non-null    object
#  5   Team     352 non-null    object
#  6   Mats     569 non-null    int64
#  7   Balls    410 non-null    float64
#  8   Mdns     410 non-null    float64
#  9   Runs     410 non-null    float64
#  10  Wkts     410 non-null    float64
#  11  BB       410 non-null    object
#  12  Ave      425 non-null    object
#  13  4wl      569 non-null    int64
#  14  5wl      569 non-null    int64
#  15  S. Rate  425 non-null    object
#  16  Econ     410 non-null    float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 80.0+ KB

# %%
df_Bowling_Data.dropna(subset = ["Team"], inplace=True)

# %%
df_Bowling_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 603
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     352 non-null    int64
#  1   Sr. No   352 non-null    int64
#  2   Name     352 non-null    object
#  3   Age      351 non-null    object
#  4   Skill    352 non-null    object
#  5   Team     352 non-null    object
#  6   Mats     352 non-null    int64
#  7   Balls    352 non-null    float64
#  8   Mdns     352 non-null    float64
#  9   Runs     352 non-null    float64
#  10  Wkts     352 non-null    float64
#  11  BB       352 non-null    object
#  12  Ave      320 non-null    object
#  13  4wl      352 non-null    int64
#  14  5wl      352 non-null    int64
#  15  S. Rate  320 non-null    object
#  16  Econ     352 non-null    float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 49.5+ KB

# %%
df_Bowling_Data
# Out:
#      Year  Sr. No             Name       Age Skill               Team  Mats  \
# 0    2016       1    Andre Russell  32 years  RAFM   Islamabad United    10
# 1    2016       2       Wahab Riaz  35 years  LAFM     Peshawar Zalmi     9
# 2    2016       3   Mohammad Nawaz  26 years   LAO  Quetta Gladiators    10
# 3    2016       4    Mohammad Sami  39 years  RAMF   Islamabad United     7
# 4    2016       5    Grant Elliott  41 years  RAFM  Quetta Gladiators     6
# ..    ...     ...              ...       ...   ...                ...   ...
# 597  2021      72      Naseem Shah  19 years  RAFM  Quetta Gladiators     3
# 598  2021      73      Sohaibullah        --  LAMF     Multan Sultans     1
# 599  2021      74        Anwar Ali  34 years  RAMF  Quetta Gladiators     1
# 600  2021      75  Jack Wildermuth  28 years  RAMF  Quetta Gladiators     2
# 603  2021      78     Khalid Usman  36 years  SLAO     Peshawar Zalmi     1
#
# ...

# %%
df_Bowling_Data.dropna(subset = ["Ave"], inplace=True)

# %%
df_Bowling_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 0 to 603
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     320 non-null    int64
#  1   Sr. No   320 non-null    int64
#  2   Name     320 non-null    object
#  3   Age      319 non-null    object
#  4   Skill    320 non-null    object
#  5   Team     320 non-null    object
#  6   Mats     320 non-null    int64
#  7   Balls    320 non-null    float64
#  8   Mdns     320 non-null    float64
#  9   Runs     320 non-null    float64
#  10  Wkts     320 non-null    float64
#  11  BB       320 non-null    object
#  12  Ave      320 non-null    object
#  13  4wl      320 non-null    int64
#  14  5wl      320 non-null    int64
#  15  S. Rate  320 non-null    object
#  16  Econ     320 non-null    float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 45.0+ KB

# %%
df_Bowling_Data
# Out:
#      Year  Sr. No             Name       Age Skill               Team  Mats  \
# 0    2016       1    Andre Russell  32 years  RAFM   Islamabad United    10
# 1    2016       2       Wahab Riaz  35 years  LAFM     Peshawar Zalmi     9
# 2    2016       3   Mohammad Nawaz  26 years   LAO  Quetta Gladiators    10
# 3    2016       4    Mohammad Sami  39 years  RAMF   Islamabad United     7
# 4    2016       5    Grant Elliott  41 years  RAFM  Quetta Gladiators     6
# ..    ...     ...              ...       ...   ...                ...   ...
# 597  2021      72      Naseem Shah  19 years  RAFM  Quetta Gladiators     3
# 598  2021      73      Sohaibullah        --  LAMF     Multan Sultans     1
# 599  2021      74        Anwar Ali  34 years  RAMF  Quetta Gladiators     1
# 600  2021      75  Jack Wildermuth  28 years  RAMF  Quetta Gladiators     2
# 603  2021      78     Khalid Usman  36 years  SLAO     Peshawar Zalmi     1
#
# ...

# %%
b=df_Bowling_Data['Age'].mode()[0]
df_Bowling_Data['Age']=df_Bowling_Data['Age'].fillna(b)

# %%
df_Bowling_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 0 to 603
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     320 non-null    int64
#  1   Sr. No   320 non-null    int64
#  2   Name     320 non-null    object
#  3   Age      320 non-null    object
#  4   Skill    320 non-null    object
#  5   Team     320 non-null    object
#  6   Mats     320 non-null    int64
#  7   Balls    320 non-null    float64
#  8   Mdns     320 non-null    float64
#  9   Runs     320 non-null    float64
#  10  Wkts     320 non-null    float64
#  11  BB       320 non-null    object
#  12  Ave      320 non-null    object
#  13  4wl      320 non-null    int64
#  14  5wl      320 non-null    int64
#  15  S. Rate  320 non-null    object
#  16  Econ     320 non-null    float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 45.0+ KB

# %%
df_Bowling_Data
# Out:
#      Year  Sr. No             Name       Age Skill               Team  Mats  \
# 0    2016       1    Andre Russell  32 years  RAFM   Islamabad United    10
# 1    2016       2       Wahab Riaz  35 years  LAFM     Peshawar Zalmi     9
# 2    2016       3   Mohammad Nawaz  26 years   LAO  Quetta Gladiators    10
# 3    2016       4    Mohammad Sami  39 years  RAMF   Islamabad United     7
# 4    2016       5    Grant Elliott  41 years  RAFM  Quetta Gladiators     6
# ..    ...     ...              ...       ...   ...                ...   ...
# 597  2021      72      Naseem Shah  19 years  RAFM  Quetta Gladiators     3
# 598  2021      73      Sohaibullah        --  LAMF     Multan Sultans     1
# 599  2021      74        Anwar Ali  34 years  RAMF  Quetta Gladiators     1
# 600  2021      75  Jack Wildermuth  28 years  RAMF  Quetta Gladiators     2
# 603  2021      78     Khalid Usman  36 years  SLAO     Peshawar Zalmi     1
#
# ...

# %%
df_Bowling_Data.hist(figsize=(18,15))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Sr. No'}>,
#         <AxesSubplot:title={'center':'Mats'}>],
#        [<AxesSubplot:title={'center':'Balls'}>,
#         <AxesSubplot:title={'center':'Mdns'}>,
#         <AxesSubplot:title={'center':'Runs'}>],
#        [<AxesSubplot:title={'center':'Wkts'}>,
#         <AxesSubplot:title={'center':'4wl'}>,
#         <AxesSubplot:title={'center':'5wl'}>],
#        [<AxesSubplot:title={'center':'Econ'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_Bowling_Data["Wkts"].value_counts()
# Out:
# 4.0     33
# 1.0     31
# 2.0     29
# 3.0     26
# 7.0     25
# 5.0     24
# 0.0     22
# 6.0     21
# 10.0    19
# 9.0     17
# 8.0     17
# 13.0    12
# 12.0    12
# 11.0    12
# 15.0     6
# 16.0     4
# 18.0     3
# 17.0     2
# 14.0     2
# 25.0     1
# 21.0     1
# 20.0     1
# Name: Wkts, dtype: int64

# %%
fig_dims=(8,5)
fig,ax=plt.subplots(figsize=fig_dims)
g=sns.countplot(x='Year', ax=ax,data=df_Bowling_Data)
g.annotate('42',xy=(0,42))
g.annotate('38',xy=(1,38))
g.annotate('51',xy=(2,51))
g.annotate('53',xy=(3,53))
g.annotate('65',xy=(4,65))
g.annotate('71',xy=(5,71))
plt.savefig("Maximum Bowlers by year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_Bowling_Data['Skill'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,rotatelabels=True,figsize=(12,10))
plt.title("Skill",fontweight="bold",fontsize=15)
plt.savefig("Percentage of same type of Bowlers")
plt.show()

# %%
df_Bowling_Data['Mats'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,rotatelabels=True,figsize=(12,10))
plt.title("Matches",fontweight="bold",fontsize=15)
plt.savefig("No of Matches Played by Each Bowler")
plt.show()

# %%
Wickets = df_Bowling_Data.groupby(['Name'])['Wkts'].sum().reset_index()
Wickets.columns = ['Name', 'Wkts']
y = Wickets.sort_values(by='Wkts', ascending = False).head(10).reset_index().drop('index', axis=1)
y
# Out:
#                   Name  Wkts
# 0           Wahab Riaz  94.0
# 1            Hasan Ali  72.0
# 2       Mohammad Nawaz  55.0
# 3       Mohammad Aamer  54.0
# 4        Sohail Tanvir  53.0
# 5  Shaheen Shah Afridi  50.0
# 6          Shadab Khan  46.0
# 7        Shahid Afridi  44.0
# 8    Mohammad Irfan Sr  43.0
# 9        Mohammad Sami  42.0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.barplot(x=y['Name'],y=y['Wkts'],palette='rocket',saturation=1)
g.annotate('94',xy=(0,94))
g.annotate('72',xy=(1,72))
g.annotate('55',xy=(2,55))
g.annotate('54',xy=(3,54))
g.annotate('53',xy=(4,53))
g.annotate('50',xy=(5,50))
g.annotate('46',xy=(6,46))
g.annotate('44',xy=(7,44))
g.annotate('43',xy=(8,43))
g.annotate('42',xy=(9,42))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Wickets',fontsize=15)
plt.title('Top 10 Wickets taker in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Wickets taker in PSL")

# %%
Ball = df_Bowling_Data.groupby(['Name'])['Balls'].sum().reset_index()
Ball.columns = ['Name', 'Balls']
z = Ball.sort_values(by='Balls', ascending = False).head(10).reset_index().drop('index', axis=1)
z
# Out:
#                   Name   Balls
# 0           Wahab Riaz  1499.0
# 1       Mohammad Aamer  1304.0
# 2            Hasan Ali  1230.0
# 3       Mohammad Nawaz  1210.0
# 4        Sohail Tanvir  1133.0
# 5    Mohammad Irfan Sr  1110.0
# 6          Shadab Khan  1108.0
# 7           Imad Wasim  1059.0
# 8        Shahid Afridi   970.0
# 9  Shaheen Shah Afridi   831.0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.barplot(x=z['Name'],y=z['Balls'],palette='rocket',saturation=1)
g.annotate('1499',xy=(0,1499))
g.annotate('1304',xy=(1,1304))
g.annotate('1230',xy=(2,1230))
g.annotate('1210',xy=(3,1210))
g.annotate('1133',xy=(4,1133))
g.annotate('1110',xy=(5,1110))
g.annotate('1108',xy=(6,1108))
g.annotate('1059',xy=(7,1059))
g.annotate('970',xy=(8,970))
g.annotate('831',xy=(9,831))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Balls',fontsize=15)
plt.title('Top 10 Players who delievered most balls in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Players who delievered most balls in PSL")

# %%
runs = df_Bowling_Data.groupby(['Name'])['Runs'].sum().reset_index()
runs.columns = ['Name', 'Runs']
a = runs.sort_values(by='Runs', ascending = False).head(10).reset_index().drop('index', axis=1)
a
# Out:
#                 Name    Runs
# 0         Wahab Riaz  1843.0
# 1     Mohammad Aamer  1602.0
# 2          Hasan Ali  1504.0
# 3      Sohail Tanvir  1447.0
# 4     Mohammad Nawaz  1446.0
# 5        Shadab Khan  1368.0
# 6  Mohammad Irfan Sr  1285.0
# 7         Imad Wasim  1245.0
# 8        Sohail Khan  1187.0
# 9      Shahid Afridi  1127.0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.barplot(x=a['Name'],y=a['Runs'],palette='rocket',saturation=1)
g.annotate('1843',xy=(0,1843))
g.annotate('1602',xy=(1,1602))
g.annotate('1504',xy=(2,1504))
g.annotate('1447',xy=(3,1447))
g.annotate('1446',xy=(4,1446))
g.annotate('1368',xy=(5,1368))
g.annotate('1285',xy=(6,1285))
g.annotate('1245',xy=(7,1245))
g.annotate('1059',xy=(8,1187))
g.annotate('1127',xy=(9,1127))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Runs',fontsize=15)
plt.title('Top 10 Players who give max runs in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Players who give max runs in PSL")

# %%
df_Batting_Data=pd.read_excel('PSL Analytics Data 2.xlsx',sheet_name="Bating Data")

# %%
df_Batting_Data
# Out:
#      Year  Sr. No                   Name       Age Skill               Team  \
# 0    2016       1             Umar Akmal        30   RHB   Lahore Qalandars
# 1    2016       2            Ravi Bopara        35   RHB      Karachi Kings
# 2    2016       3          Sharjeel Khan        31   LHB   Islamabad United
# 3    2016       4          Ahmed Shehzad        28  RHOB  Quetta Gladiators
# 4    2016       5            Tamim Iqbal        31   LHB     Peshawar Zalmi
# ..    ...     ...                    ...       ...   ...                ...
# 651  2021     126         Arish Ali Khan  21 years   RHB                NaN
# 652  2021     127               Ali Khan  31 years   RHB                NaN
# 653  2021     128  Mohammad Salman Mirza  28 years   RHB                NaN
# 654  2021     129            Zahoor Khan  33 years   RHB                NaN
# 655  2021     130       Waqar Salamkheil  20 years   RHB                NaN
#
#      Mats  Inns  N.O.   Runs     HS    AVG  100  50
# ...

# %%
df_Batting_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    656 non-null    int64
#  1   Sr. No  656 non-null    int64
#  2   Name    656 non-null    object
#  3   Age     656 non-null    object
#  4   Skill   655 non-null    object
#  5   Team    483 non-null    object
#  6   Mats    656 non-null    int64
#  7   Inns    656 non-null    int64
#  8   N.O.    656 non-null    int64
#  9   Runs    616 non-null    float64
#  10  HS      616 non-null    float64
#  11  AVG     656 non-null    object
#  12  100     656 non-null    int64
#  13  50      656 non-null    int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 71.9+ KB

# %%
df_Batting_Data
# Out:
#      Year  Sr. No                   Name       Age Skill               Team  \
# 0    2016       1             Umar Akmal        30   RHB   Lahore Qalandars
# 1    2016       2            Ravi Bopara        35   RHB      Karachi Kings
# 2    2016       3          Sharjeel Khan        31   LHB   Islamabad United
# 3    2016       4          Ahmed Shehzad        28  RHOB  Quetta Gladiators
# 4    2016       5            Tamim Iqbal        31   LHB     Peshawar Zalmi
# ..    ...     ...                    ...       ...   ...                ...
# 651  2021     126         Arish Ali Khan  21 years   RHB                NaN
# 652  2021     127               Ali Khan  31 years   RHB                NaN
# 653  2021     128  Mohammad Salman Mirza  28 years   RHB                NaN
# 654  2021     129            Zahoor Khan  33 years   RHB                NaN
# 655  2021     130       Waqar Salamkheil  20 years   RHB                NaN
#
#      Mats  Inns  N.O.   Runs     HS    AVG  100  50
# ...

# %%
a=df_Batting_Data['Skill'].mode()[0]
df_Batting_Data['Skill']=df_Batting_Data['Skill'].fillna(a)

# %%
c=df_Batting_Data['Runs'].mean()
df_Batting_Data['Runs']=df_Batting_Data['Runs'].fillna(c)

# %%
d=df_Batting_Data['HS'].mean()
df_Batting_Data['HS']=df_Batting_Data['HS'].fillna(d)

# %%
df_Batting_Data.hist(figsize=(18,15))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Sr. No'}>,
#         <AxesSubplot:title={'center':'Mats'}>],
#        [<AxesSubplot:title={'center':'Inns'}>,
#         <AxesSubplot:title={'center':'N.O.'}>,
#         <AxesSubplot:title={'center':'Runs'}>],
#        [<AxesSubplot:title={'center':'HS'}>,
#         <AxesSubplot:title={'center':'100'}>,
#         <AxesSubplot:title={'center':'50'}>]], dtype=object)

# %%
df_Batting_Data['Skill'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,rotatelabels=True,figsize=(12,10))
plt.title("Skill",fontweight="bold",fontsize=15)
plt.savefig("Percentage of same type of Batsman")
plt.show()

# %%
df_Batting_Data['Mats'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,rotatelabels=True,figsize=(12,10))
plt.title("Mats",fontweight="bold",fontsize=15)
plt.savefig("No of Matches Played by Each Batsman")
plt.show()

# %%
runs = df_Batting_Data.groupby(['Name'])['Runs'].sum().reset_index()
runs.columns = ['Name', 'Runs']
f = runs.sort_values(by='Runs', ascending = False).head(10).reset_index().drop('index', axis=1)
f
# Out:
#               Name    Runs
# 0       Babar Azam  2070.0
# 1     Kamran Akmal  1820.0
# 2     Shoaib Malik  1481.0
# 3     Shane Watson  1361.0
# 4     Fakhar Zaman  1351.0
# 5  Mohammad Hafeez  1272.0
# 6   Sarfaraz Ahmed  1189.0
# 7    Rilee Rossouw  1139.0
# 8    Ahmed Shehzad  1077.0
# 9      Luke Ronchi  1020.0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
g=sns.barplot(x=f['Name'],y=f['Runs'],palette='rocket',saturation=1)
g.annotate('2070',xy=(0,2070))
g.annotate('1820',xy=(1,1820))
g.annotate('1481',xy=(2,1481))
g.annotate('1361',xy=(3,1361))
g.annotate('1351',xy=(4,1351))
g.annotate('1272',xy=(5,1272))
g.annotate('1189',xy=(6,1189))
g.annotate('1139',xy=(7,1139))
g.annotate('1077',xy=(8,1077))
g.annotate('1020',xy=(9,1020))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Runs',fontsize=15)
plt.title('Top 10 Batsman by Score in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Batsman by Score in PSL")

# %%
runs = df_Batting_Data.groupby(['Name'])['HS'].sum().reset_index()
runs.columns = ['Name', 'HS']
g = runs.sort_values(by='HS', ascending = False).head(10).reset_index().drop('index', axis=1)
g
# Out:
#               Name     HS
# 0     Kamran Akmal  502.0
# 1  Mohammad Hafeez  380.0
# 2     Shane Watson  376.0
# 3       Babar Azam  376.0
# 4     Fakhar Zaman  361.0
# 5     Shoaib Malik  355.0
# 6    Rilee Rossouw  335.0
# 7   Sarfaraz Ahmed  326.0
# 8  Cameron Delport  317.0
# 9    Sharjeel Khan  297.0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
w=sns.barplot(x=g['Name'],y=g['HS'],palette='rocket',saturation=1)
w.annotate('502',xy=(0,502))
w.annotate('380',xy=(1,380))
w.annotate('376',xy=(2,376))
w.annotate('376',xy=(3,376))
w.annotate('361',xy=(4,361))
w.annotate('355',xy=(5,355))
w.annotate('335',xy=(6,335))
w.annotate('326',xy=(7,326))
w.annotate('317',xy=(8,317))
w.annotate('297',xy=(9,297))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Runs',fontsize=15)
plt.title('Top 10 Batsman by Highest Score in one season of PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Batsman by Highest Score in one season of PSL")

# %%
innings = df_Batting_Data.groupby(['Name'])['Inns'].sum().reset_index()
innings.columns = ['Name', 'Inns']
h = innings.sort_values(by='Inns', ascending = False).head(10).reset_index().drop('index', axis=1)
h
# Out:
#               Name  Inns
# 0     Kamran Akmal    68
# 1     Shoaib Malik    57
# 2       Babar Azam    56
# 3  Mohammad Hafeez    55
# 4   Sarfaraz Ahmed    53
# 5     Fakhar Zaman    50
# 6    Rilee Rossouw    49
# 7     Shane Watson    46
# 8         Asif Ali    46
# 9       Imad Wasim    45

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
w=sns.barplot(x=h['Name'],y=h['Inns'],palette='rocket',saturation=1)
w.annotate('68',xy=(0,68))
w.annotate('57',xy=(1,57))
w.annotate('56',xy=(2,56))
w.annotate('55',xy=(3,55))
w.annotate('53',xy=(4,53))
w.annotate('50',xy=(5,50))
w.annotate('49',xy=(6,49))
w.annotate('46',xy=(7,46))
w.annotate('46',xy=(8,46))
w.annotate('45',xy=(9,45))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('Total Inns',fontsize=15)
plt.title('Top 10 Batsman who played most Innings in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Batsman who played most Innings in PSL")

# %%
fifty = df_Batting_Data.groupby(['Name'])['50'].sum().reset_index()
fifty.columns = ['Name', '50']
i = fifty.sort_values(by='50', ascending = False).head(10).reset_index().drop('index', axis=1)
i
# Out:
#               Name  50
# 0       Babar Azam  21
# 1     Kamran Akmal  11
# 2      Luke Ronchi  10
# 3     Shane Watson   9
# 4     Shoaib Malik   9
# 5     Fakhar Zaman   9
# 6    Ahmed Shehzad   9
# 7  Mohammad Hafeez   8
# 8       Umar Akmal   7
# 9   Sohaib Maqsood   7

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
w=sns.barplot(x=i['Name'],y=i['50'],palette='rocket',saturation=1)
w.annotate('21',xy=(0,21))
w.annotate('11',xy=(1,11))
w.annotate('10',xy=(2,10))
w.annotate('9',xy=(3,9))
w.annotate('9',xy=(4,9))
w.annotate('9',xy=(5,9))
w.annotate('9',xy=(6,9))
w.annotate('8',xy=(7,8))
w.annotate('7',xy=(8,7))
w.annotate('7',xy=(9,7))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('No of Fifty',fontsize=15)
plt.title('Top 10 Batsman who made most fifty in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Batsman who made most fifty in PSL")

# %%
hun = df_Batting_Data.groupby(['Name'])['100'].sum().reset_index()
hun.columns = ['Name', '100']
j = hun.sort_values(by='100', ascending = False).head(10).reset_index().drop('index', axis=1)
j
# Out:
#                  Name  100
# 0        Kamran Akmal    3
# 1       Sharjeel Khan    2
# 2        Colin Ingram    1
# 3       Rilee Rossouw    1
# 4       Usman Khawaja    1
# 5     Cameron Delport    1
# 6          Chris Lynn    1
# 7  Rahmanullah Gurbaz    0
# 8           Rahat Ali    0
# 9  Rafatullah Mohmand    0

# %%
ax = plt.axes()
ax.set(facecolor = "grey")
w=sns.barplot(x=j['Name'],y=j['100'],palette='rocket',saturation=1)
w.annotate('3',xy=(0,3))
w.annotate('2',xy=(1,2))
w.annotate('1',xy=(2,1))
w.annotate('1',xy=(3,1))
w.annotate('1',xy=(4,1))
w.annotate('1',xy=(5,1))
w.annotate('1',xy=(6,1))
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('\n Player',fontsize=15)
plt.ylabel('No of Hundreds',fontsize=15)
plt.title('Top 10 Batsman who made most hundred in PSL',fontsize=15,fontweight="bold")
plt.savefig("Top 10 Batsman who made most hundred in PSL")

# %%
for team in df["Team_1"].unique():
     print(team)
# Out:
# Islamabad United
# Karachi Kings
# Peshawar Zalmi
# Quetta Gladiators
# Lahore Qalandars
# Multan Sultans
# Multan Sultans
# Lahore Qalandars
# Karachi Kings

# %%
 from sklearn import preprocessing

# %%
data=df.copy()

# %%
encoder= preprocessing.LabelEncoder()
data["Team_1"]=encoder.fit_transform(data["Team_1"])
data["Team_2"]=encoder.fit_transform(data["Team_2"])
data["Match Winner"]=encoder.fit_transform(data["Match Winner"].astype(str))
data["Toss_Winner"]=encoder.fit_transform(data["Toss_Winner"])
data["Grounds"]=encoder.fit_transform(data["Grounds"])

# %%
data.loc[data["Match Winner"]==data["Team_1"],"Team_1_win"]=1
data.loc[data["Match Winner"]!=data["Team_1"],"Team_1_win"]=0

#outcome variable team1_toss_win as a value of team1 winning the toss
data.loc[data["Toss_Winner"]==data["Team_1"],"Team_1_toss_win"]=1
data.loc[data["Toss_Winner"]!=data["Team_1"],"Team_1_toss_win"]=0

#outcome variable team1_bat to depict if team1 bats first
data["Team_1_bat"]=0
data.loc[(data["Team_1_toss_win"]==1) & (data["Toss_Decision"]=="bat"),"Team_1_bat"]=1

# %%
prediction_df=data[["Team_1","Team_2","Team_1_toss_win","Team_1_bat","Team_1_win","Grounds"]]

#finding the higly correlated features
correlated_features = set()
correlation_matrix = prediction_df.drop('Team_1_win', axis=1).corr()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.9:
            column = correlation_matrix.columns[i]
            correlated_features.add(column)
            
prediction_df.drop(columns=correlated_features)
# Out:
#      Team_1  Team_2  Team_1_toss_win  Team_1_bat  Team_1_win  Grounds
# 0         0       5              0.0           0         0.0        0
# 1         2       2              1.0           0         1.0        0
# 2         7       0              0.0           0         0.0        0
# 3         8       1              0.0           0         0.0        0
# 4         4       4              0.0           0         0.0        0
# ..      ...     ...              ...         ...         ...      ...
# 145       8       1              0.0           0         0.0        4
# 146       5       1              0.0           0         0.0        4
# 147       3       4              1.0           0         1.0        4
# 148       5       2              0.0           0         0.0        4
# 149       1       2              0.0           0         0.0        4
#
# [150 rows x 6 columns]

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.savefig("Correlation matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = prediction_df.iloc[:, :-1].values
y = prediction_df.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
#Decision Tree Classifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
y_pred = dtree.predict(X_test)
print('Accuracy of Decision Tree Classifier on test set: {:.4f}'.format(dtree.score(X_test, y_test)))

#Random Forest Classifier
randomForest= RandomForestClassifier(n_estimators=100)
randomForest.fit(X_train,y_train)
y_pred = randomForest.predict(X_test)
print('Accuracy of Random Forest Classifier on test set: {:.4f}'.format(randomForest.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree Classifier on test set: 0.7233
# Accuracy of Random Forest Classifier on test set: 0.6233

# %%
y_pred = dtree.predict([[3,1,1,0,0]])#1

# %%
y_pred
# Out:
# array([1])

# %%
dtree.predict([[5,4,0,0,0]])#2
# Out:
# array([0])

# %%
dtree.predict([[3,2,1,0,0]])#3
# Out:
# array([1])

# %%
dtree.predict([[5,1,1,0,0]])#4
# Out:
# array([1])

# %%
dtree.predict([[4,0,1,0,0]])#5
# Out:
# array([1])

# %%
dtree.predict([[2,1,1,0,0]])#6
# Out:
# array([0])

# %%
dtree.predict([[5,3,1,0,0]])#7
# Out:
# array([1])

# %%
dtree.predict([[3,0,1,0,0]])#8
# Out:
# array([1])

# %%
dtree.predict([[4,2,1,0,0]])#9
# Out:
# array([1])

# %%
dtree.predict([[5,0,1,0,0]])#10
# Out:
# array([1])

# %%
dtree.predict([[4,1,1,0,0]])#11
# Out:
# array([1])

# %%
dtree.predict([[2,0,1,0,0]])#12
# Out:
# array([0])

# %%
dtree.predict([[4,3,1,0,0]])#13
# Out:
# array([1])

# %%
dtree.predict([[1,0,0,1,0]])#14
# Out:
# array([0])

# %%
dtree.predict([[5,2,1,0,0]])#15
# Out:
# array([1])

# %%
dtree.predict([[4,3,1,0,1]])#16
# Out:
# array([1])

# %%
dtree.predict([[3,2,1,0,1]])#17
# Out:
# array([1])

# %%
dtree.predict([[5,0,1,0,1]])#18
# Out:
# array([1])

# %%
dtree.predict([[4,2,1,0,1]])#19
# Out:
# array([1])

# %%
dtree.predict([[5,2,1,0,1]])#20
# Out:
# array([1])

# %%
X = prediction_df[['Team_1','Team_2','Team_1_bat','Grounds']]
y = prediction_df['Team_1_win']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,shuffle=True)

# %%
#Decision Tree Classifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
y_pred = dtree.predict(X_test)
print('Accuracy of Decision Tree Classifier on test set: {:.4f}'.format(dtree.score(X_test, y_test)))

#Random Forest Classifier
randomForest= RandomForestClassifier(n_estimators=100)
randomForest.fit(X_train,y_train)
y_pred = randomForest.predict(X_test)
print('Accuracy of Random Forest Classifier on test set: {:.4f}'.format(randomForest.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree Classifier on test set: 0.7667
# Accuracy of Random Forest Classifier on test set: 0.8000

# %%
y_pred = dtree.predict([[5,4,0,0]])

# %%
y_pred
# Out:
# array([0.])
